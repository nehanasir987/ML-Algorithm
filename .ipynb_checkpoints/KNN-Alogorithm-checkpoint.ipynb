# %%
#Problem Staments:

# %%
import numpy as np  #handling a numerical data efficiently
import pandas as pd #is used for data handling and analysis.--provides tools like DataFrames to easily load, explore, clean, and prepare datasets.
from sklearn.model_selection import train_test_split #split your dataset into: Training or testing
from sklearn.preprocessing import StandardScaler
#Machine learning models understand numbers, but they perform best when all numbers are on the same scale (range). so like age is 20 , 30 ,40 ,50 or income is 10,000
# , 20,000 - 30,000 Here, income has much larger values than age,--so the model might give more importance to income just because its numbers are bigger — even if it’s not actually more important.
from sklearn.neighbors import KNeighborsClassifier #imports the K-Nearest Neighbors (KNN) algorithm — 
#a popular classification algorithm.--effective for small datasets, and requires no explicit training phase.

# %%
# Create dataset with 9 rows and 3 columns (age, salary, past_purchases)
data = np.array([
    [22, 25000, 2],
    [25, 30000, 3],
    [28, 35000, 4],
    [30, 40000, 5],
    [32, 45000, 6],
    [35, 50000, 7],
    [38, 55000, 8],
    [40, 60000, 9],
    [42, 65000, 10]
])


# Labels: 0 = Low, 1 = Medium, 2 = High
labels = np.array([0, 0, 1, 1, 1, 2, 2, 2, 2])

# Print both arrays
print("Data:\n", data)
print("\nLabels:\n", labels)
# Out:
# Data:
#  [[   22 25000     2]
#  [   25 30000     3]
#  [   28 35000     4]
#  [   30 40000     5]
#  [   32 45000     6]
#  [   35 50000     7]
#  [   38 55000     8]
#  [   40 60000     9]
#  [   42 65000    10]]
#
# Labels:
#  [0 0 1 1 1 2 2 2 2]

# %%
# Split into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
